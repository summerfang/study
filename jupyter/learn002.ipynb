# %%
import pandas as pd 
import plotnine as p9

df = pd.read_csv("test.csv")

p9.ggplot(data=df, mapping=p9.aes(x='city_development_index',y='training_hours')) + p9.geom_point()
# Out:
# <ggplot: (-9223371903332715372)>
