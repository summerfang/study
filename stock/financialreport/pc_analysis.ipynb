# %%
from find_available_qrd_pair import get_success_ratio, draw_normal_distribution

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Ticker = 'PANW'
success_ratio, distribution = get_success_ratio(Ticker, 366.41, 331.37, 406.13)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    46.000000
# mean      1.723972
# std       8.937630
# min     -24.154049
# 25%      -2.356710
# 50%       3.422965
# 75%       7.258930
# max      18.600524
# dtype: float64
# ------------------
# PANW 25.72%
# Low Z-Score (0.10% percentile): -9.56 (Probability: 0.10)
# High Z-Score (0.85% percentile): 10.84 (Probability: 0.85)

# %%
Ticker = 'HD'
success_ratio, distribution = get_success_ratio(Ticker, 362.35, 345.45, 377.05)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    92.000000
# mean     -0.155151
# std       1.852859
# min      -5.240079
# 25%      -1.041915
# 50%      -0.109850
# 75%       0.741959
# max       8.033059
# dtype: float64
# ------------------
# HD 1.90%
# Low Z-Score (0.01% percentile): -4.66 (Probability: 0.01)
# High Z-Score (0.99% percentile): 4.06 (Probability: 0.99)

# %%
Ticker = 'NVDA'
success_ratio, distribution = get_success_ratio(Ticker, 725.13, 646.42, 808.58)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# count    95.000000
# mean      1.863687
# std      10.497716
# min     -35.233527
# 25%      -3.189181
# 50%       1.731606
# 75%       7.044667
# max      33.063519
# dtype: float64
# ------------------
# NVDA 29.20%
# Low Z-Score (0.11% percentile): -10.85 (Probability: 0.11)
# High Z-Score (0.82% percentile): 11.51 (Probability: 0.82)

# %%
Ticker = 'RIO'
success_ratio, distribution = get_success_ratio(Ticker, 40.32, 39.07, 41.93)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    9.000000
# mean     0.228563
# std      1.943484
# min     -2.341063
# 25%     -1.029770
# 50%     -0.056735
# 75%      1.887102
# max      2.625137
# dtype: float64
# ------------------
# RIO 6.98%
# Low Z-Score (0.04% percentile): -3.10 (Probability: 0.04)
# High Z-Score (0.97% percentile): 3.99 (Probability: 0.97)

# %%
Ticker = 'ADI'
success_ratio, distribution = get_success_ratio(Ticker, 188.24, 179.4, 198.1)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-12-01 -> 2023-12-01)')
# count    95.000000
# mean      0.580885
# std       4.646749
# min     -16.206897
# 25%      -1.647010
# 50%      -0.214975
# 75%       2.782703
# max      15.646255
# dtype: float64
# ------------------
# ADI 28.62%
# Low Z-Score (0.13% percentile): -4.70 (Probability: 0.13)
# High Z-Score (0.84% percentile): 5.24 (Probability: 0.84)

# %%
Ticker = 'SNPS'
success_ratio, distribution = get_success_ratio(Ticker, 552.91, 505.45, 605.55)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2018-12-05, skipping...
# count    94.000000
# mean      0.726810
# std       6.689639
# min     -31.156019
# 25%      -2.618983
# 50%       1.114235
# 75%       4.719489
# max      15.756378
# dtype: float64
# ------------------
# SNPS 17.63%
# Low Z-Score (0.08% percentile): -8.58 (Probability: 0.08)
# High Z-Score (0.91% percentile): 9.52 (Probability: 0.91)

# %%
Ticker = 'RIVN'
success_ratio, distribution = get_success_ratio(Ticker, 16.3, 13.94, 19.06)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    10.000000
# mean      0.354595
# std      12.707789
# min     -18.341964
# 25%      -9.298241
# 50%      -1.269695
# 75%      11.653326
# max      17.961159
# dtype: float64
# ------------------
# RIVN 21.76%
# Low Z-Score (0.12% percentile): -14.48 (Probability: 0.12)
# High Z-Score (0.90% percentile): 16.93 (Probability: 0.90)

# %%
Ticker = 'TCOM'
success_ratio, distribution = get_success_ratio(Ticker, 41.24, 37.9, 45.1)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2023-09-04, skipping...
# Error: 2016-11-23, skipping...
# Error: 2012-02-20, skipping...
# Error: 2011-11-13, skipping...
# Error: 2011-02-13, skipping...
# Error: 2009-02-08, skipping...
# Error: 2007-02-11, skipping...
# count    77.000000
# mean      1.203742
# std       8.952364
# min     -19.018582
# 25%      -3.684208
# 50%       0.182338
# 75%       6.412215
# max      25.756308
# dtype: float64
# ------------------
# TCOM 33.05%
# Low Z-Score (0.15% percentile): -8.10 (Probability: 0.15)
# High Z-Score (0.82% percentile): 9.36 (Probability: 0.82)

# %%
Ticker = 'NU'
success_ratio, distribution = get_success_ratio(Ticker, 10.36,  9.54, 11.46)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2021-10-08, skipping...
# count     9.000000
# mean      2.095626
# std      11.211363
# min     -14.545457
# 25%      -6.206896
# 50%       0.164200
# 75%      12.873562
# max      17.948722
# dtype: float64
# ------------------
# NU 40.95%
# Low Z-Score (0.19% percentile): -7.92 (Probability: 0.19)
# High Z-Score (0.78% percentile): 10.62 (Probability: 0.78)

# %%
Ticker = 'MELI'
success_ratio, distribution = get_success_ratio(Ticker, 1768.78, 1624.05, 1908.45)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    65.000000
# mean      4.094812
# std       9.849166
# min     -18.521080
# 25%      -2.668222
# 50%       3.649300
# 75%      11.601783
# max      30.936618
# dtype: float64
# ------------------
# MELI 45.60%
# Low Z-Score (0.11% percentile): -8.18 (Probability: 0.11)
# High Z-Score (0.65% percentile): 7.90 (Probability: 0.65)

# %%
Ticker = 'INTU'
success_ratio, distribution = get_success_ratio(Ticker, 655.74, 618, 689.5)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    95.000000
# mean      1.905887
# std       6.855044
# min     -13.261441
# 25%      -1.952606
# 50%       1.360985
# 75%       5.922028
# max      29.561201
# dtype: float64
# ------------------
# INTU 45.00%
# Low Z-Score (0.13% percentile): -5.76 (Probability: 0.13)
# High Z-Score (0.68% percentile): 5.15 (Probability: 0.68)

# %%
Ticker = 'BKNG'
success_ratio, distribution = get_success_ratio(Ticker, 3716.80, 3482.55, 3927.45)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    95.000000
# mean      1.885555
# std      11.394010
# min     -31.050228
# 25%      -2.404021
# 50%       2.211497
# 75%       7.594616
# max      32.489450
# dtype: float64
# ------------------
# BKNG 60.62%
# Low Z-Score (0.24% percentile): -6.30 (Probability: 0.24)
# High Z-Score (0.63% percentile): 5.67 (Probability: 0.63)

# %%
Ticker = 'SQ'
success_ratio, distribution = get_success_ratio(Ticker, 65.64, 56.85, 74.15)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2021-08-01, skipping...
# count    32.000000
# mean      1.736821
# std       9.573983
# min     -21.685823
# 25%      -4.226619
# 50%       2.912820
# 75%       8.486812
# max      26.139596
# dtype: float64
# ------------------
# SQ 17.75%
# Low Z-Score (0.06% percentile): -13.39 (Probability: 0.06)
# High Z-Score (0.88% percentile): 12.96 (Probability: 0.88)

# %%
Ticker = 'COLD'
success_ratio, distribution = get_success_ratio(Ticker, 27.18, 24.27, 30.73)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    25.000000
# mean      1.452659
# std       5.384437
# min      -6.800528
# 25%      -2.989304
# 50%       0.845330
# 75%       4.059724
# max      15.298041
# dtype: float64
# ------------------
# COLD 2.75%
# Low Z-Score (0.01% percentile): -10.71 (Probability: 0.01)
# High Z-Score (0.98% percentile): 13.06 (Probability: 0.98)

# %%
Ticker = 'ALTR'
success_ratio, distribution = get_success_ratio(Ticker,90.47, 83.82, 101.18)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# count    26.000000
# mean      0.109355
# std       7.490188
# min     -19.935951
# 25%      -3.822122
# 50%       1.307337
# 75%       5.082951
# max      12.321020
# dtype: float64
# ------------------
# ALTR 21.83%
# Low Z-Score (0.16% percentile): -7.35 (Probability: 0.16)
# High Z-Score (0.94% percentile): 11.84 (Probability: 0.94)

# %%
Ticker = 'RHP'
success_ratio, distribution = get_success_ratio(Ticker, 116.24, 110.02, 124.98)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 1999-10-28, skipping...
# Error: 1999-07-29, skipping...
# Error: 1999-04-22, skipping...
# Error: 1999-02-10, skipping...
# Error: 1998-10-29, skipping...
# Error: 1998-07-29, skipping...
# Error: 1998-04-23, skipping...
# Error: 1998-02-17, skipping...
# Error: 1998-01-14, skipping...
# Error: 1997-07-23, skipping...
# Error: 1997-05-06, skipping...
# Error: 1997-02-10, skipping...
# count    83.000000
# mean      0.159318
# std       2.819001
# min      -9.837056
# 25%      -0.825563
# 50%       0.235150
# 75%       1.780422
# max       7.614213
# dtype: float64
# ------------------
# RHP 2.98%
# Low Z-Score (0.03% percentile): -5.35 (Probability: 0.03)
# High Z-Score (1.00% percentile): 7.52 (Probability: 1.00)

# %%
Ticker = 'WBD'
success_ratio, distribution = get_success_ratio(Ticker, 9.83, 8.83, 11.17)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2008-02-15, skipping...
# count    73.000000
# mean     -0.514644
# std       3.522080
# min     -16.533178
# 25%      -1.874998
# 50%      -0.529800
# 75%       1.591520
# max       8.378587
# dtype: float64
# ------------------
# WBD 0.31%
# Low Z-Score (0.00% percentile): -10.17 (Probability: 0.00)
# High Z-Score (1.00% percentile): 13.63 (Probability: 1.00)

# %%
Ticker = 'BRK-B'
success_ratio, distribution = get_success_ratio(Ticker, 405.99, 400.77, 411.73)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2023-11-04, skipping...
# Error: 2023-08-05, skipping...
# Error: 2023-05-06, skipping...
# Error: 2023-02-25, skipping...
# Error: 2022-11-05, skipping...
# Error: 2022-04-30, skipping...
# Error: 2021-11-07, skipping...
# Error: 2021-08-07, skipping...
# Error: 2021-05-01, skipping...
# Error: 2021-02-27, skipping...
# Error: 2020-11-07, skipping...
# Error: 2020-08-08, skipping...
# Error: 2020-05-02, skipping...
# Error: 2020-02-22, skipping...
# Error: 2019-11-03, skipping...
# Error: 2019-11-02, skipping...
# Error: 2019-08-03, skipping...
# Error: 2019-05-04, skipping...
# Error: 2019-02-23, skipping...
# Error: 2018-11-03, skipping...
# Error: 2018-08-04, skipping...
# Error: 2018-05-05, skipping...
# Error: 2018-02-24, skipping...
# Error: 2017-02-25, skipping...
# Error: 2016-02-27, skipping...
# Error: 2015-02-28, skipping...
# Error: 2014-03-01, skipping...
# Error: 2011-02-26, skipping...
# ...

# %%
Ticker = 'ADSK'
success_ratio, distribution = get_success_ratio(Ticker, 258.3, 239.10, 275.9)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADSK']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-12-01 -> 2023-12-01)')
# Error: 1999-11-23, skipping...
# count    94.000000
# mean      0.419267
# std       8.286381
# min     -17.749463
# 25%      -4.946847
# 50%       0.493896
# 75%       5.980034
# max      16.894977
# dtype: float64
# ------------------
# ADSK 39.18%
# Low Z-Score (0.17% percentile): -7.43 (Probability: 0.17)
# High Z-Score (0.78% percentile): 6.81 (Probability: 0.78)

# %%
Ticker = 'PYPL'
success_ratio, distribution = get_success_ratio(Ticker, 59.14, 56.25, 60.75)
print('------------------')
print(f'{Ticker} {success_ratio:.2f}%')

draw_normal_distribution(distribution[0], distribution[1], distribution[2], distribution[3])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Error: 2024-02-07, skipping...
# Error: 2015-07-01, skipping...
# count    34.000000
# mean      0.365402
# std       8.206269
# min     -24.590441
# 25%      -4.165640
# 50%       1.592474
# 75%       6.478569
# max      14.012934
# dtype: float64
# ------------------
# PYPL 64.81%
# Low Z-Score (0.26% percentile): -4.89 (Probability: 0.26)
# High Z-Score (0.61% percentile): 2.72 (Probability: 0.61)
