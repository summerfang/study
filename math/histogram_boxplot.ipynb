# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = fetch_california_housing(as_frame=True)
df = data.frame

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
print(df['AveBedrms'].mean())
print(df['AveBedrms'].median())
print(df['AveBedrms'].mode())
print(df['AveBedrms'].std())
print(df['AveBedrms'].var())
print(df['AveBedrms'].quantile(0.25))
print(df['AveBedrms'].quantile(0.75))
print(df['AveBedrms'].quantile(0.75) - df['AveBedrms'].quantile(0.25))
print(df['AveBedrms'].describe())
print(df['AveBedrms'].describe()['75%'] - df['AveBedrms'].describe()['25%'])
# Out:
# 1.096675149606208
# 1.048780487804878
# 0    1.0
# Name: AveBedrms, dtype: float64
# 0.473910856795466
# 0.2245915001886127
# 1.006079046038478
# 1.099526066350711
# 0.09344702031223284
# count    20640.000000
# mean         1.096675
# std          0.473911
# min          0.333333
# 25%          1.006079
# 50%          1.048780
# 75%          1.099526
# max         34.066667
# Name: AveBedrms, dtype: float64
# 0.09344702031223284

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

plt.plot(x, y)

# %%
plt.plot(x, y, ':', lw=5, animated=True)
y_cos = np.cos(x)
plt.plot(x, y_cos, 'r--', lw=5, animated=True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('sin(x)') 
plt.legend(['sin', 'cos'])
plt.show()
